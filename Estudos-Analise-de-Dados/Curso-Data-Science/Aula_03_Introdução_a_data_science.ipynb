# %% [markdown]
# <a href="https://colab.research.google.com/github/evercodde/evercodde/blob/main/Estudos-Analise-de-Dados/Curso-Data-Science/Aula_03_Introdu%C3%A7%C3%A3o_a_data_science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importando a biblioteca pandas

# %%
import pandas as pd

# %% [markdown]
# Carregando um arquivo csv no pandas e exibindo

# %%
notas = pd.read_csv("https://raw.githubusercontent.com/alura-cursos/data-science-analise-exploratoria/main/Aula_0/ml-latest-small/ratings.csv")
notas
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %% [markdown]
# Consultando a quantidade de linhas e colunas com o atributo shape

# %%
notas.shape
# Out:
# (100836, 4)

# %% [markdown]
# Mudando o nome das colunas  e exibindo apenas os 5 primeiros elementos com columns = [] e head()

# %%
notas.columns = ["usuarioId", "filmeId", "nota", "momento"]
notas.head()
# Out:
#    usuarioId  filmeId  nota    momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %% [markdown]
# Exibindo apenas os valores unicos com unique()

# %%
notas["nota"].unique()
# Out:
# array([4. , 5. , 3. , 2. , 1. , 4.5, 3.5, 2.5, 0.5, 1.5])

# %% [markdown]
# Exibindo a quantidade de cada aparição com value_counts()

# %%
notas["nota"].value_counts()
# Out:
# nota
# 4.0    26818
# 3.0    20047
# 5.0    13211
# 3.5    13136
# 4.5     8551
# 2.0     7551
# 2.5     5550
# 1.0     2811
# 1.5     1791
# 0.5     1370
# Name: count, dtype: int64

# %% [markdown]
# Exibindo a Media com .mean()

# %%
notas["nota"].mean()
# Out:
# 3.501556983616962
